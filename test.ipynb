# %%
import pandas as pd

# %%
df = pd.read_csv("dataset_final/train_data.csv")

# %%
df.head(10)
# Out:
#    LEFT_HIP_x  LEFT_HIP_y  LEFT_HIP_z  LEFT_HIP_visibility  RIGHT_HIP_x  \
# 0   -0.435229    0.087919   -0.616714             0.993745    -0.031399
# 1    0.064270   -0.465139   -0.486558             0.999716     0.577379
# 2   -0.532243   -0.639196    0.225317             0.862202     0.166742
# 3   -0.158615   -0.074836    0.336764             0.999503    -0.088373
# 4   -0.432757   -0.447512    0.976354             0.998824    -0.868170
# 5    0.533035   -0.068080    1.119479             0.998768     0.297710
# 6   -0.855978    1.448796    0.597163             0.997465    -0.890367
# 7    0.717791    2.615054   -0.514588             0.991235     0.202171
# 8   -0.665214   -0.631818    0.530503             0.997090    -0.850821
# 9    0.492373   -0.530826   -0.755701             0.999785     1.072302
#
#    RIGHT_HIP_y  RIGHT_HIP_z  RIGHT_HIP_visibility  LEFT_KNEE_x  LEFT_KNEE_y  \
# 0     0.014560     0.629697              0.994968    -0.493523    -0.468006
# ...

# %%
df.describe()
# Out:
#         LEFT_HIP_x   LEFT_HIP_y   LEFT_HIP_z  LEFT_HIP_visibility  \
# count  1989.000000  1989.000000  1989.000000          1989.000000
# mean     -0.016537     0.000914    -0.006785             0.993111
# std       1.013133     0.963277     0.996958             0.029486
# min      -5.758258   -10.275888    -6.841539             0.506266
# 25%      -0.491398    -0.476403    -0.549642             0.995929
# 50%       0.110849    -0.256476    -0.062758             0.998347
# 75%       0.492441     0.247979     0.507641             0.999345
# max       3.001803     2.620913     8.348129             0.999918
#
#        RIGHT_HIP_x  RIGHT_HIP_y  RIGHT_HIP_z  RIGHT_HIP_visibility  \
# count  1989.000000  1989.000000  1989.000000           1989.000000
# mean     -0.012670     0.000474     0.006726              0.993560
# std       1.015373     0.962535     0.997119              0.026638
# min      -4.576855   -10.911095    -8.347926              0.529005
# ...

# %%
# Check the column names in the dataframe
print(df.columns)

# Assuming the correct column name is 'activity_label', update the plot code
plt.figure(figsize=(8, 6))
sns.countplot(x='activity_encoded', data=df, palette='viridis')
plt.title('Distribución de las actividades (activity_label)', fontsize=16)
plt.xlabel('Actividad', fontsize=12)
plt.ylabel('Cantidad', fontsize=12)
plt.xticks(rotation=45)
plt.show()
# Out:
# Index(['LEFT_HIP_x', 'LEFT_HIP_y', 'LEFT_HIP_z', 'LEFT_HIP_visibility',
#        'RIGHT_HIP_x', 'RIGHT_HIP_y', 'RIGHT_HIP_z', 'RIGHT_HIP_visibility',
#        'LEFT_KNEE_x', 'LEFT_KNEE_y', 'LEFT_KNEE_z', 'LEFT_KNEE_visibility',
#        'RIGHT_KNEE_x', 'RIGHT_KNEE_y', 'RIGHT_KNEE_z', 'RIGHT_KNEE_visibility',
#        'LEFT_ANKLE_x', 'LEFT_ANKLE_y', 'LEFT_ANKLE_z', 'LEFT_ANKLE_visibility',
#        'RIGHT_ANKLE_x', 'RIGHT_ANKLE_y', 'RIGHT_ANKLE_z',
#        'RIGHT_ANKLE_visibility', 'LEFT_WRIST_x', 'LEFT_WRIST_y',
#        'LEFT_WRIST_z', 'LEFT_WRIST_visibility', 'RIGHT_WRIST_x',
#        'RIGHT_WRIST_y', 'RIGHT_WRIST_z', 'RIGHT_WRIST_visibility',
#        'LEFT_SHOULDER_x', 'LEFT_SHOULDER_y', 'LEFT_SHOULDER_z',
#        'LEFT_SHOULDER_visibility', 'RIGHT_SHOULDER_x', 'RIGHT_SHOULDER_y',
#        'RIGHT_SHOULDER_z', 'RIGHT_SHOULDER_visibility', 'NOSE_x', 'NOSE_y',
#        'NOSE_z', 'NOSE_visibility', 'LEFT_KNEE_ANGLE', 'RIGHT_KNEE_ANGLE',
# ...
